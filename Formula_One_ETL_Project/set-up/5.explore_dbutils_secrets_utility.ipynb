# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope = 'formula-one-scope')

# %%
dbutils.secrets.get(scope='formula-one-scope', key='formula-one-dl-account-key')
